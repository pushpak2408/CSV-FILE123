# %% [markdown]
# <a href="https://colab.research.google.com/github/pushpak2408/CSV-FILE123/blob/main/MODULE2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
mca=pd.read_csv("https://raw.githubusercontent.com/pushpak2408/project/refs/heads/main/info2.csv")
print(mca)
# Out:
#    Duration  Average_Pulse  Max_Pulse  Calorie_Burnage  Hours_Work  \
# 0        30             80        120              240          10
# 1        45             85        120              250          10
# 2        45             90        130              260           8
# 3        60             95        130              270           8
# 4        60            100        140              280           0
# 5        60            105        140              290           7
# 6        60            110        145              300           7
# 7        45            115        145              310           8
# 8        60            120        150              320           0
# 9        45            125        150              330           8
#
#    Hours_Sleep
# 0            7
# 1            7
# 2            7
# 3            7
# 4            7
# 5            8
# 6            8
# 7            8
# 8            8
# 9            8

# %%
#to plot a straight line using dataset
import matplotlib.pyplot as plt
mca.plot(x='Average_Pulse',y='Calorie_Burnage',kind='line')
plt.ylim(ymin=30)
plt.xlim(xmin=50)
plt.show()

# %%
#write a user define function to calculate slope
def slope(x1,y1,x2,y2):
  m=(y2-y1)/(x2-x1)
  return m
print(slope(50,30,60,40))
# Out:
# 1.0

# %%
#calculate slope and intercept using polyfit
import numpy as np
x=mca['Average_Pulse']
y=mca['Calorie_Burnage']
slope_intercept=np.polyfit(x,y,1)
print(slope_intercept)
# Out:
# [ 2. 80.]

# %%
#userdefine function for calculation of caloriburnage
def Calorie_Burnage(x1,slope=2,intercept=80):
  s=(slope*x1)+intercept
  return s
print(Calorie_Burnage(125))
# Out:
# 330

# %%
#write code to scatter values maintoring min and new limit
import matplotlib.pyplot as plt
mca.plot(x='Average_Pulse',y='Calorie_Burnage',kind='scatter')
plt.ylim(ymin=30)
plt.xlim(xmin=50)
plt.show()
