# %% [markdown]
# <a href="https://colab.research.google.com/github/pushpak2408/CSV-FILE123/blob/main/MODULE4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# Read CSV file
mca = pd.read_csv("https://raw.githubusercontent.com/pushpak2408/project/refs/heads/main/info3.csv", header=0, sep=",")

# Display first few rows to verify data loading
mca
# Out:
#      Duration  Average_Pulse  Max_Pulse  Calorie_Burnage  Hours_Work  \
# 0          60            110        130              409         0.0
# 1          60            117        145              479         0.0
# 2          60            103        135              340         8.0
# 3          45            109        175              282         8.0
# 4          45            117        148              406         0.0
# ..        ...            ...        ...              ...         ...
# 158        60            105        140              290         7.0
# 159        60            110        145              300         7.0
# 160        60            115        145              310         8.0
# 161        75            120        150              320         0.0
# 162        75            125        150              330         8.0
#
#      Hours_Sleep
# 0            8.0
# 1            8.0
# 2            7.5
# 3            8.0
# 4            6.5
# ..           ...
# ...

# %%
# Extract columns
x = mca['Average_Pulse']
y = mca['Calorie_Burnage']

# Perform linear regression
slope, intercept, r, p, std_err = stats.linregress(x, y)

# Print results
print("Slope:", slope)
print("Intercept:", intercept)
print("Correlation Coefficient (r):", r)
print("P-value:", p)
print("Standard Error:", std_err)
# Out:
# Slope: 0.3295634736556583
# Intercept: 346.8662267857687
# Correlation Coefficient (r): 0.017576257945091003
# P-value: 0.8237776479944345
# Standard Error: 1.4775174665775799

# %%
def myfunction(x):
  return slope * x + intercept

new_y=myfunction(x)
print(new_y)
# Out:
# 0      383.118209
# 1      385.425153
# 2      380.811265
# 3      382.788645
# 4      385.425153
#           ...
# 158    381.470392
# 159    383.118209
# 160    384.766026
# 161    386.413844
# 162    388.061661
# Name: Average_Pulse, Length: 163, dtype: float64

# %%
plt.figure(figsize=(7, 5))
plt.scatter(x, y)
plt.plot(x, new_y)
plt.xlabel('Average_Pulse')
plt.ylabel('Calorie_Burnage')
plt.show()

# %%
import pandas as pd
import statsmodels.formula.api as smf
mca=pd.read_csv("https://raw.githubusercontent.com/pushpak2408/project/refs/heads/main/info3.csv")
mca
# Out:
#      Duration  Average_Pulse  Max_Pulse  Calorie_Burnage  Hours_Work  \
# 0          60            110        130              409         0.0
# 1          60            117        145              479         0.0
# 2          60            103        135              340         8.0
# 3          45            109        175              282         8.0
# 4          45            117        148              406         0.0
# ..        ...            ...        ...              ...         ...
# 158        60            105        140              290         7.0
# 159        60            110        145              300         7.0
# 160        60            115        145              310         8.0
# 161        75            120        150              320         0.0
# 162        75            125        150              330         8.0
#
#      Hours_Sleep
# 0            8.0
# 1            8.0
# 2            7.5
# 3            8.0
# 4            6.5
# ..           ...
# ...

# %%
model=smf.ols('Calorie_Burnage~Average_Pulse',data=mca).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:        Calorie_Burnage   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.006
# Method:                 Least Squares   F-statistic:                   0.04975
# Date:                Wed, 02 Apr 2025   Prob (F-statistic):              0.824
# Time:                        07:04:29   Log-Likelihood:                -1145.8
# No. Observations:                 163   AIC:                             2296.
# Df Residuals:                     161   BIC:                             2302.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept       346.8662    160.615      2.160      0.032      29.682     664.050
# ...
